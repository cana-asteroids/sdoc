# %% [markdown]
# # Creating or updating SDOC
#
# Basic usage example of the sdoc database.
#
# We will search for a optical constant data and plot it.

# %%
import sdoc
import pandas as pd

# %% [markdown]
# ### 1. Load the database and see the contents

# %% [markdown]
# Before updating the database, all other instances must be closed.

# %%
sdb = sdoc.SDOC(mode='r+')

# %%
sdb.contents
# Out:
#          oid  mid    material formula     group phase  temp  wmin      wmax  \
# ict_0  ict_0  ict  Ice Tholin          organics     -   NaN   0.3  5.304851
#
#        res                hpath ref
# ict_0  972  /organics/ict/ict_0   -

# %% [markdown]
# #### To clean database uncomment the following line (do not umcomment if just adding new optical constants):

# %%
# sdb.clean()
sdb.contents
# Out:
# Empty DataFrame
# Columns: [oid, mid, material, formula, group, phase, temp, wmin, wmax, res, hpath, ref]
# Index: []

# %% [markdown]
# ### 2. Inserting a single new optical constant

# %% [markdown]
# #### To insert a new optical constant, each of the parameters bellow need to be informed:

# %%
print(sdb.insert_constant.__doc__)
# Out:
#         Insert an optical constant to the SDOC database.
#
#         To save the changes you must close the database:
#         ..: sdb = SDOC(mode="r+")
#         ..: sdb.insert_constant(...)
#         ..: sdb.close()
#
#         Parameters
#         ----------
#         group: str
#             The name of the compositional group (e.g. Organics, Silicates,
#             Ices...).
#
#         material: str
#             The full name of the compound material (e.g. Titan Tholin,
#             Serpentine).
#
#         mid: str
#             The ID for the compound (e.g. H, W, Ss). If none, it will search
#             for the standard IDs from ___. However it will raise an error if
#             mid is not assigned and the compound is not found in the list.
#             To see all the compound IDs use .... If mid=None and is not found
#             in the list of IDs, it will set mid='U' (for undefined).
#
#         ocpath: str
#             The path for the optical constant file. The file must have three
#             columns: wavelength, real refractory index, imaginary refractory
#             index.
#
#         oid: str (optional)
#             The database identifier for the optical constant. If no value
#             is given, it will create as "mid_n", where mid is the material
#             identifier provided, and n is number of optical constants in
#             the database +1.
#
#         ref: str (optional)
#             The name of the reference for the optical constant
#
#         phase: string (optional)
#             The phase of the material (amorphous, crystalline)
#
#         temperature: float (optional)
#             The temperature of the material
#
#         formula: str (optional)
#             The chemical formula of the optical constants

# %%
# example of insertion

sdb.insert_constant(group='organics',
                    material='Ice Tholin',
                    mid='ict',
                    oid='ict_0',
                    ocpath='/home/mario/sync/artigos/disco/centaurs_javier/notebooks/optcon_icetholin1.txt')

# %%
# example of insertion

sdb.insert_constant(group='ices',
                    material='CO2',
                    mid='cod',
                    oid='cod_0',
                    temp='15K'
                    ocpath='/home/mario/sync/artigos/disco/centaurs_javier/notebooks/optcon_icetholin1.txt')

# %%
sdb.contents
# Out:
#          oid  mid    material formula     group phase  temp  wmin      wmax  \
# ict_0  ict_0  ict  Ice Tholin          organics     -   NaN   0.3  5.304851
#
#        res                hpath ref
# ict_0  972  /organics/ict/ict_0   -

# %% [markdown]
# ### 3. Read the CSV file with the information of the new optical constants

# %% [markdown]
# The CSV file must contain the information accordingly to the demonstrated bellow.
#
# Values for min, wmax and res are not used as they are obtained from the optical constants files.
#
# Values for oid, group, formula, phase, temp and ref are optional.

# %%
catalog = pd.read_csv('../sdoc/data/sdoc.csv')
catalog
# Out:
#       oid  mid         material                   formula      group  \
# 0   car_0  car           Carbon               Kbr embebed     carbon
# 1   car_1  car           Carbon                  Graphite     carbon
# 2   nit_0  nit         Nitrogen                        N2       ices
# 3   eta_0  eta           Ethane                      C2H6       ices
# 4   eta_1  eta           Ethane                      C2H6       ices
# 5   eta_2  eta           Ethane                      C2H6       ices
# 6   eta_3  eta           Ethane                      C2H6       ices
# 7   eta_4  eta           Ethane                      C2H6       ices
# 8   eth_0  eth         Ethylene                      C2H4       ices
# 9   eth_1  eth         Ethylene                      C2H4       ices
# 10  eth_2  eth         Ethylene                      C2H4       ices
# 11  eth_3  eth         Ethylene                      C2H4       ices
# 12  amo_3  amo          Ammonia                       NH3       ices
# 13  cod_1  cod   Carbon dioxide                       CO2       ices
# 14  com_0  com  Carbon monoxide                        CO       ices
# 15  mol_0  mol         Methanol                     CH3OH       ices
# 16  met_0  met          Methane                       CH4       ices
# 17  wat_2  wat            Water                       H2O       ices
# 18  wat_4  wat            Water                       H2O       ices
# 19  wat_5  wat            Water                       H2O       ices
# 20  wat_6  wat            Water                       H2O       ices
# 21  m03_0  m03        Mixture 3            NH3(1)-N2(1.7)   mixtures
# 22  m04_0  m04        Mixture 4            H2O(20)-CH4(1)   mixtures
# 23  m05_0  m05        Mixture 5                    CH4-N2   mixtures
# 24  trt_0  tri    Triton Tholin                         -   organics
# 25  tit_0  tit     Titan Tholin                         -   organics
# 26  pyr_1  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# 27  pyr_2  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.60  silicates
# 28  pyr_3  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.70  silicates
# 29  pyr_4  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.80  silicates
# 30  pyr_5  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.95  silicates
# 31  pyr_6  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=1.00  silicates
# 32  oli_0  oli          Olivine  Mg_2y,Fe_2-2y,SiO4,y=0.5  silicates
# 33  oli_1  oli          Olivine  Mg_2y,Fe_2-2y,SiO4,y=0.4  silicates
#
#           phase   temp  wmin     wmax  res                 hpath  \
# 0     amorphous    50K   0.3  4.99002  470     /carbon/car_0.txt
# 1             -    20K   0.3  4.99002  470     /carbon/car_1.txt
# 2             -  36.5K   0.3  4.99002  470       /ices/nit_0.txt
# 3   crystalline    30K   0.3  4.99002  470       /ices/eta_0.txt
# 4   crystalline    40K   0.3  4.99002  470       /ices/eta_1.txt
# 5     amorphous    30K   0.3  4.99002  470       /ices/eta_2.txt
# 6     amorphous    40K   0.3  4.99002  470       /ices/eta_3.txt
# 7     amorphous    60K   0.3  4.99002  470       /ices/eta_4.txt
# 8     amorphous    30K   0.3  4.99002  470       /ices/eth_0.txt
# 9     amorphous    40K   0.3  4.99002  470       /ices/eth_1.txt
# 10  crystalline    30K   0.3  4.99002  470       /ices/eth_2.txt
# 11  crystalline    40K   0.3  4.99002  470       /ices/eth_3.txt
# 12    amorphous    40K   0.3  4.99002  470       /ices/amo_3.txt
# 13            -   150K   0.3  4.99002  469       /ices/cod_1.txt
# 14            -    10K   0.3  4.99002  470       /ices/com_0.txt
# 15            -   100K   0.3  4.99002  470       /ices/mol_0.txt
# 16  crystalline    39K   0.3  4.99002  470       /ices/met_0.txt
# 17    amorphous    40K   0.3  4.99002  470       /ices/wat_2.txt
# 18  crystalline    40K   0.3  4.99002  470       /ices/wat_4.txt
# 19  crystalline    50K   0.3  4.99002  470       /ices/wat_5.txt
# 20    amorphous    50K   0.3  4.99002  470       /ices/wat_6.txt
# 21            -    15K   0.3  4.99002  470   /mixtures/m03_0.txt
# 22            -    40K   0.3  4.99002  470   /mixtures/m04_0.txt
# 23         beta    38K   0.3  4.99002  470   /mixtures/m05_0.txt
# 24            -      -   0.3  4.99002  470   /organics/trt_0.txt
# 25            -      -   0.3  4.99002  470   /organics/tit_0.txt
# 26            -      -   0.3  4.99002  470  /silicates/pyr_1.txt
# 27            -      -   0.3  4.99002  470  /silicates/pyr_2.txt
# 28            -      -   0.3  4.99002  470  /silicates/pyr_3.txt
# 29            -      -   0.3  4.99002  470  /silicates/pyr_4.txt
# 30            -      -   0.3  4.99002  470  /silicates/pyr_5.txt
# 31            -      -   0.2  5.50000   42  /silicates/pyr_6.txt
# 32            -      -   0.3  4.99002  470  /silicates/oli_0.txt
# 33            -      -   0.3  4.99002  470  /silicates/oli_1.txt
#
#                                   ref
# 0               Rouleau & Martin 1991
# 1                         Draine 1985
# 2                    B.Schmitt et al.
# 3                  Hudson et al. 2014
# 4                  Hudson et al. 2014
# 5                  Hudson et al. 2014
# 6                  Hudson et al. 2014
# 7                  Hudson et al. 2014
# 8                  Hudson et al. 2014
# 9                  Hudson et al. 2014
# 10                 Hudson et al. 2014
# 11                 Hudson et al. 2014
# 12                  Roser et al. 2021
# 13                 Hansen et al. 1997
# 14                            PubChem
# 15  Hudgins et al 1993 and Brown 1995
# 16      SShade and Grundy et al. 2002
# 17     Mastrapa et al., 2008 and 2009
# 18     Mastrapa et al., 2008 and 2009
# 19     Mastrapa et al., 2008 and 2009
# 20     Mastrapa et al., 2008 and 2009
# 21                Zanchet et al. 2013
# 22                 Hudgins et al 1993
# 23   Quirico and schmitt 1992, SShade
# 24                              Khare
# 25                   Khare et al 1984
# 26              Dorschner et al. 1995
# 27              Dorschner et al. 1995
# 28              Dorschner et al. 1995
# 29              Dorschner et al. 1995
# 30              Dorschner et al. 1995
# 31              Dorschner et al. 1995
# 32              Dorschner et al. 1995
# 33              Dorschner et al. 1995

# %% [markdown]
# #### Inserting new data to the database

# %%
sdb.insert_constants_csv('../sdoc/data/sdoc.csv', basedir='../sdoc/data/oc_files/')

# %%
sdb.contents
# Out:
#          oid  mid         material                   formula      group  \
# car_0  car_0  car           Carbon               Kbr embebed     carbon
# car_1  car_1  car           Carbon               Kbr embebed     carbon
# amo_3  amo_3  amo          Ammonia                       NH3       ices
# cod_1  cod_1  cod   Carbon dioxide                       CO2       ices
# com_0  com_0  com  Carbon monoxide                        CO       ices
# eta_0  eta_0  eta           Ethane                      C2H6       ices
# eta_1  eta_1  eta           Ethane                      C2H6       ices
# eta_2  eta_2  eta           Ethane                      C2H6       ices
# eta_3  eta_3  eta           Ethane                      C2H6       ices
# eta_4  eta_4  eta           Ethane                      C2H6       ices
# eth_0  eth_0  eth         Ethylene                      C2H4       ices
# eth_1  eth_1  eth         Ethylene                      C2H4       ices
# eth_2  eth_2  eth         Ethylene                      C2H4       ices
# eth_3  eth_3  eth         Ethylene                      C2H4       ices
# met_0  met_0  met          Methane                       CH4       ices
# mol_0  mol_0  mol         Methanol                     CH3OH       ices
# nit_0  nit_0  nit         Nitrogen                        N2       ices
# wat_2  wat_2  wat            Water                       H2O       ices
# wat_4  wat_4  wat            Water                       H2O       ices
# wat_5  wat_5  wat            Water                       H2O       ices
# wat_6  wat_6  wat            Water                       H2O       ices
# m03_0  m03_0  m03        Mixture 3            NH3(1)-N2(1.7)   mixtures
# m04_0  m04_0  m04        Mixture 4            H2O(20)-CH4(1)   mixtures
# m05_0  m05_0  m05        Mixture 5                    CH4-N2   mixtures
# ict_0  ict_0  ict       Ice Tholin                             organics
# tit_0  tit_0  tit     Titan Tholin                         -   organics
# trt_0  trt_0  tri    Triton Tholin                         -   organics
# oli_0  oli_0  oli          Olivine  Mg_2y,Fe_2-2y,SiO4,y=0.5  silicates
# oli_1  oli_1  oli          Olivine  Mg_2y,Fe_2-2y,SiO4,y=0.5  silicates
# pyr_1  pyr_1  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# pyr_2  pyr_2  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# pyr_3  pyr_3  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# pyr_4  pyr_4  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# pyr_5  pyr_5  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
# pyr_6  pyr_6  pyr         Pyroxene   Mg_x,Fe_1-x,SiO3,x=0.50  silicates
#
#              phase   temp  wmin      wmax  res                 hpath  \
# car_0    amorphous    50K   0.3  4.990020  470     /carbon/car/car_0
# car_1            -    20K   0.3  4.990020  470     /carbon/car/car_1
# amo_3    amorphous    40K   0.3  4.990020  470       /ices/amo/amo_3
# cod_1            -   150K   0.3  4.990020  469       /ices/cod/cod_1
# com_0            -    10K   0.3  4.990020  470       /ices/com/com_0
# eta_0  crystalline    30K   0.3  4.990020  470       /ices/eta/eta_0
# eta_1  crystalline    40K   0.3  4.990020  470       /ices/eta/eta_1
# eta_2    amorphous    30K   0.3  4.990020  470       /ices/eta/eta_2
# eta_3    amorphous    40K   0.3  4.990020  470       /ices/eta/eta_3
# eta_4    amorphous    60K   0.3  4.990020  470       /ices/eta/eta_4
# eth_0    amorphous    30K   0.3  4.990020  470       /ices/eth/eth_0
# eth_1    amorphous    40K   0.3  4.990020  470       /ices/eth/eth_1
# eth_2  crystalline    30K   0.3  4.990020  470       /ices/eth/eth_2
# eth_3  crystalline    40K   0.3  4.990020  470       /ices/eth/eth_3
# met_0  crystalline    39K   0.3  4.990020  470       /ices/met/met_0
# mol_0            -   100K   0.3  4.990020  470       /ices/mol/mol_0
# nit_0            -  36.5K   0.3  4.990020  470       /ices/nit/nit_0
# wat_2    amorphous    40K   0.3  4.990020  470       /ices/wat/wat_2
# wat_4  crystalline    40K   0.3  4.990020  470       /ices/wat/wat_4
# wat_5  crystalline    50K   0.3  4.990020  470       /ices/wat/wat_5
# wat_6    amorphous    50K   0.3  4.990020  470       /ices/wat/wat_6
# m03_0            -    15K   0.3  4.990020  470   /mixtures/m03/m03_0
# m04_0            -    40K   0.3  4.990020  470   /mixtures/m04/m04_0
# m05_0         beta    38K   0.3  4.990020  470   /mixtures/m05/m05_0
# ict_0            -    NaN   0.3  5.304851  972   /organics/ict/ict_0
# tit_0            -      -   0.3  4.990020  470   /organics/tit/tit_0
# trt_0            -      -   0.3  4.990020  470   /organics/tri/trt_0
# oli_0            -      -   0.3  4.990020  470  /silicates/oli/oli_0
# oli_1            -      -   0.3  4.990020  470  /silicates/oli/oli_1
# pyr_1            -      -   0.3  4.990020  470  /silicates/pyr/pyr_1
# pyr_2            -      -   0.3  4.990020  470  /silicates/pyr/pyr_2
# pyr_3            -      -   0.3  4.990020  470  /silicates/pyr/pyr_3
# pyr_4            -      -   0.3  4.990020  470  /silicates/pyr/pyr_4
# pyr_5            -      -   0.3  4.990020  470  /silicates/pyr/pyr_5
# pyr_6            -      -   0.2  5.500000   42  /silicates/pyr/pyr_6
#
#                                      ref
# car_0              Rouleau & Martin 1991
# car_1                        Draine 1985
# amo_3                  Roser et al. 2021
# cod_1                 Hansen et al. 1997
# com_0                            PubChem
# eta_0                 Hudson et al. 2014
# eta_1                 Hudson et al. 2014
# eta_2                 Hudson et al. 2014
# eta_3                 Hudson et al. 2014
# eta_4                 Hudson et al. 2014
# eth_0                 Hudson et al. 2014
# eth_1                 Hudson et al. 2014
# eth_2                 Hudson et al. 2014
# eth_3                 Hudson et al. 2014
# met_0      SShade and Grundy et al. 2002
# mol_0  Hudgins et al 1993 and Brown 1995
# nit_0                   B.Schmitt et al.
# wat_2     Mastrapa et al., 2008 and 2009
# wat_4     Mastrapa et al., 2008 and 2009
# wat_5     Mastrapa et al., 2008 and 2009
# wat_6     Mastrapa et al., 2008 and 2009
# m03_0                Zanchet et al. 2013
# m04_0                 Hudgins et al 1993
# m05_0   Quirico and schmitt 1992, SShade
# ict_0                                  -
# tit_0                   Khare et al 1984
# trt_0                              Khare
# oli_0              Dorschner et al. 1995
# oli_1              Dorschner et al. 1995
# pyr_1              Dorschner et al. 1995
# pyr_2              Dorschner et al. 1995
# pyr_3              Dorschner et al. 1995
# pyr_4              Dorschner et al. 1995
# pyr_5              Dorschner et al. 1995
# pyr_6              Dorschner et al. 1995

# %% [markdown]
# ### 4. Saving and closing

# %% [markdown]
# To ensure all data is saved properly close the database

# %%
sdb.close()
